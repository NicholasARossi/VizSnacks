# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('rossidata')

# %%
titles=['Table 9 89 means','Table 9 92 means','Table 9 95 means','Table 9 98 means','Table 9 01 means','Table 9 04 means','Table 9 07 means','Table 9 10 means','Table 9 13 means','Table 9 16 means']

list=[]
xls = pd.ExcelFile('data.xlsx')
for title in titles:
    df1 = pd.read_excel(xls, title)

    df1.columns = ['class','Vehicles', 'Primary residence','Other residential property','Equity in nonresidential property','Business equity','Other','Any nonfinancial asset','any asset']
    # df2 = pd.read_excel(xls, 'Sheet2')
    df1=df1.dropna()
    df1=df1.set_index('class')
    list.append(df1)
titles=['Table 9 89','Table 9 92','Table 9 95','Table 9 98','Table 9 01','Table 9 04','Table 9 07','Table 9 10','Table 9 13','Table 9 16']
list_median=[]
for title in titles:
    df1 = pd.read_excel(xls, title)

    df1.columns = ['class','Vehicles', 'Primary residence','Other residential property','Equity in nonresidential property','Business equity','Other','Any nonfinancial asset','any asset']
    # df2 = pd.read_excel(xls, 'Sheet2')
    df1=df1.dropna()
    df1=df1.set_index('class')
    list_median.append(df1)

titles=['Table 6 89 means','Table 6 92 means','Table 6 95 means','Table 6 98 means','Table 6 01 means','Table 6 04 means','Table 6 07 means','Table 6 10 means','Table 6 13 means','Table 6 16 means']
capital_means=[]
for title in titles:
    df1 = pd.read_excel(xls, title)
    df1.columns=['Family characteristic','Transaction accounts','Certificates of deposit',
 'Savings bonds',
 'Bonds',
 'Stocks',
 'Pooled investment funds',
 'Retirement  accounts',
 'Cash value life insurance',
 'Other managed assets',
 'Other ',
 'Any financial asset']


    df1=df1.drop(df1.index[[0]])
    df1=df1.dropna()
    df1=df1.set_index('Family characteristic')
    capital_means.append(df1)

titles=['Table 6 89','Table 6 92','Table 6 95','Table 6 98','Table 6 01','Table 6 04','Table 6 07','Table 6 10','Table 6 13','Table 6 16']
capital_medians=[]
for title in titles:
    df1 = pd.read_excel(xls, title)
    df1.columns=['Family characteristic','Transaction accounts','Certificates of deposit',
 'Savings bonds',
 'Bonds',
 'Stocks',
 'Pooled investment funds',
 'Retirement  accounts',
 'Cash value life insurance',
 'Other managed assets',
 'Other ',
 'Any financial asset']
    df1=df1.drop(df1.index[[0]])
    df1=df1.dropna()
    df1=df1.set_index('Family characteristic')
    capital_medians.append(df1)

# %%
df1
# Out:
#                                         Transaction accounts  \
# Family characteristic
# Family characteristic                   Transaction accounts
# All families                                              98
# Less than 20                                            94.2
# 20–39.9                                                 96.3
# 40–59.9                                                 99.4
# 60–79.9                                                 99.9
# 80–89.9                                                 99.8
# 90–100                                                   100
# Less than 35                                            97.7
# 35–44                                                   97.3
# 45–54                                                   98.5
# 55–64                                                     98
# 65–74                                                   98.6
# 75 or more                                              97.8
# Single with child(ren)                                  97.4
# Single, no child, age less than 55                      96.8
# Single, no child, age 55 or more                        97.2
# Couple with child(ren)                                  98.6
# Couple, no child                                        98.6
# No high school diploma                                  93.2
# High school diploma                                     97.6
# Some college                                            98.6
# College degree                                          99.5
# White non-Hispanic                                        99
# Black or African-American non-hispanic                  95.9
# Hispanic or Latino                                      93.9
# Other or Multiple Race                                  98.2
# Working for someone else                                98.3
# Self-employed                                             99
# Retired                                                 97.8
# ...                                                      ...
# Couple, no child                                           9
# No high school diploma                                   0.9
# High school diploma                                      2.1
# Some college                                             3.5
# College degree                                            15
# White non-Hispanic                                         7
# Black or African-American non-hispanic                   1.4
# Hispanic or Latino                                       1.5
# Other or Multiple Race                                     4
# Working for someone else                                 4.4
# Self-employed                                           10.3
# Retired                                                  4.3
# Other not working                                        0.8
# Managerial or professional                                11
# Technical, sales, or services                              3
# Other occupation                                         2.3
# Retired or other not working                               3
# Northeast                                                6.4
# Midwest                                                  4.8
# South                                                    3.4
# West                                                     5.5
# Metropolitan statistical area (MSA)                        5
# Non-MSA                                                  2.7
# Owner                                                      9
# Renter or other                                          1.2
# Less than 25                                             0.7
# 25–49.9                                                  2.3
# 50–74.9                                                  7.5
# 75–89.9                                                 23.7
# 90–100                                                    79
#
#                                         Certificates of deposit  \
# Family characteristic
# Family characteristic                   Certificates of deposit
# All families                                                6.5
# Less than 20                                                2.9
# 20–39.9                                                     5.1
# 40–59.9                                                     6.3
# 60–79.9                                                     6.7
# 80–89.9                                                    11.5
# 90–100                                                     11.5
# Less than 35                                                2.4
# 35–44                                                       4.7
# 45–54                                                       4.6
# 55–64                                                       6.7
# 65–74                                                      10.5
# 75 or more                                                 14.5
# Single with child(ren)                                      3.3
# Single, no child, age less than 55                          3.5
# Single, no child, age 55 or more                            8.2
# Couple with child(ren)                                      5.7
# Couple, no child                                            9.2
# No high school diploma                                      2.6
# High school diploma                                         4.8
# Some college                                                  7
# College degree                                              8.9
# White non-Hispanic                                            8
# Black or African-American non-hispanic                      3.8
# Hispanic or Latino                                          2.7
# Other or Multiple Race                                        5
# Working for someone else                                    5.2
# Self-employed                                               7.1
# Retired                                                     9.7
# ...                                                         ...
# Couple, no child                                             25
# No high school diploma                                       10
# High school diploma                                        24.8
# Some college                                                 15
# College degree                                               25
# White non-Hispanic                                         22.2
# Black or African-American non-hispanic                       10
# Hispanic or Latino                                            5
# Other or Multiple Race                                       15
# Working for someone else                                     10
# Self-employed                                                50
# Retired                                                      32
# Other not working                                             *
# Managerial or professional                                 20.2
# Technical, sales, or services                               7.6
# Other occupation                                            5.2
# Retired or other not working                                 30
# Northeast                                                    13
# Midwest                                                      25
# South                                                        20
# West                                                       24.8
# Metropolitan statistical area (MSA)                          20
# Non-MSA                                                      23
# Owner                                                      24.8
# Renter or other                                               6
# Less than 25                                                3.3
# 25–49.9                                                       5
# 50–74.9                                                      16
# 75–89.9                                                      25
# 90–100                                                       55
#
#                                         Savings bonds  Bonds  Stocks  \
# Family characteristic
# Family characteristic                   Savings bonds  Bonds  Stocks
# All families                                      8.6    1.2    13.9
# Less than 20                                      2.7      *     3.9
# 20–39.9                                           5.1      *       6
# 40–59.9                                           8.6      *    10.5
# 60–79.9                                          11.3      1    13.8
# 80–89.9                                            15    1.6    25.1
# 90–100                                           15.8      6    45.9
# Less than 35                                      5.8      *      10
# 35–44                                            10.2      *    11.4
# 45–54                                             9.3    0.6    14.6
# 55–64                                             8.6    1.6    15.5
# 65–74                                             9.7    2.7    15.2
# 75 or more                                        9.1    2.4    19.6
# Single with child(ren)                              7      *     5.2
# Single, no child, age less than 55                4.1      *     9.8
# Single, no child, age 55 or more                  5.7    1.9    12.5
# Couple with child(ren)                           12.8    0.8    15.5
# Couple, no child                                  9.2    1.9    19.1
# No high school diploma                            1.8      *       4
# High school diploma                               6.3    0.4     7.2
# Some college                                      8.3    0.8     9.9
# College degree                                   13.2    2.7      26
# White non-Hispanic                               11.3    1.7    17.5
# Black or African-American non-hispanic            3.7      *     4.7
# Hispanic or Latino                                1.6      *     4.2
# Other or Multiple Race                            5.8      *    14.2
# Working for someone else                          9.3    0.7    13.8
# Self-employed                                     8.4    2.1    18.6
# Retired                                           8.1      2    13.8
# ...                                               ...    ...     ...
# Couple, no child                                  1.5    135      46
# No high school diploma                            0.6      *     9.4
# High school diploma                               0.6     45      15
# Some college                                        1    100      10
# College degree                                      1  139.9      40
# White non-Hispanic                                  1    100      30
# Black or African-American non-hispanic            0.8      *     7.5
# Hispanic or Latino                                0.3      *    10.5
# Other or Multiple Race                            0.8      *      20
# Working for someone else                          0.8  151.5    17.5
# Self-employed                                       1  310.1      60
# Retired                                             3     80    62.5
# Other not working                                 1.8      *    24.3
# Managerial or professional                          1    330      30
# Technical, sales, or services                     0.6    230      10
# Other occupation                                  0.5      *       8
# Retired or other not working                      2.8   67.7      60
# Northeast                                           1  393.3      30
# Midwest                                           0.6     40      15
# South                                               1     80      35
# West                                                1    100      30
# Metropolitan statistical area (MSA)                 1    135      29
# Non-MSA                                           0.5     30      15
# Owner                                               1    100      30
# Renter or other                                   0.5   63.9      10
# Less than 25                                      0.3      *     1.7
# 25–49.9                                           0.5      *     3.3
# 50–74.9                                           0.8      *       7
# 75–89.9                                             2     50      28
# 90–100                                              3    386     200
#
#                                           Pooled investment funds  \
# Family characteristic
# Family characteristic                   Pooled\ninvestment\nfunds
# All families                                                   10
# Less than 20                                                  1.6
# 20–39.9                                                       3.2
# 40–59.9                                                       5.4
# 60–79.9                                                      12.5
# 80–89.9                                                      17.6
# 90–100                                                       37.3
# Less than 35                                                  4.8
# 35–44                                                         6.9
# 45–54                                                         9.9
# 55–64                                                        12.6
# 65–74                                                        13.3
# 75 or more                                                   15.6
# Single with child(ren)                                        3.1
# Single, no child, age less than 55                            6.4
# Single, no child, age 55 or more                              9.4
# Couple with child(ren)                                        9.8
# Couple, no child                                             15.5
# No high school diploma                                          2
# High school diploma                                           3.5
# Some college                                                  6.6
# College degree                                               20.7
# White non-Hispanic                                           13.3
# Black or African-American non-hispanic                        1.7
# Hispanic or Latino                                            1.7
# Other or Multiple Race                                        9.7
# Working for someone else                                      9.2
# Self-employed                                                  14
# Retired                                                      11.5
# ...                                                           ...
# Couple, no child                                              224
# No high school diploma                                        215
# High school diploma                                           100
# Some college                                                   70
# College degree                                              153.2
# White non-Hispanic                                            131
# Black or African-American non-hispanic                       27.1
# Hispanic or Latino                                             19
# Other or Multiple Race                                         87
# Working for someone else                                       75
# Self-employed                                               300.9
# Retired                                                       200
# Other not working                                              95
# Managerial or professional                                    110
# Technical, sales, or services                                  61
# Other occupation                                              100
# Retired or other not working                                  175
# Northeast                                                     148
# Midwest                                                       102
# South                                                         105
# West                                                          150
# Metropolitan statistical area (MSA)                           131
# Non-MSA                                                      85.1
# Owner                                                         150
# Renter or other                                                39
# Less than 25                                                    *
# 25–49.9                                                       7.8
# 50–74.9                                                        30
# 75–89.9                                                        95
# 90–100                                                        550
#
#                                         Retirement  accounts  \
# Family characteristic
# Family characteristic                   Retirement  accounts
# All families                                            52.1
# Less than 20                                            11.3
# 20–39.9                                                 33.6
# 40–59.9                                                 53.1
# 60–79.9                                                 75.2
# 80–89.9                                                 82.2
# 90–100                                                  91.9
# Less than 35                                            42.2
# 35–44                                                   56.7
# 45–54                                                   59.8
# 55–64                                                   59.3
# 65–74                                                   49.8
# 75 or more                                              40.8
# Single with child(ren)                                  34.5
# Single, no child, age less than 55                      42.9
# Single, no child, age 55 or more                        37.9
# Couple with child(ren)                                  62.7
# Couple, no child                                          62
# No high school diploma                                  19.7
# High school diploma                                     40.5
# Some college                                            49.6
# College degree                                          74.9
# White non-Hispanic                                      60.4
# Black or African-American non-hispanic                  33.6
# Hispanic or Latino                                      29.7
# Other or Multiple Race                                    48
# Working for someone else                                  62
# Self-employed                                             52
# Retired                                                 37.5
# ...                                                      ...
# Couple, no child                                       109.8
# No high school diploma                                    36
# High school diploma                                       36
# Some college                                              34
# College degree                                         116.9
# White non-Hispanic                                        77
# Black or African-American non-hispanic                  24.6
# Hispanic or Latino                                      22.6
# Other or Multiple Race                                  52.5
# Working for someone else                                  47
# Self-employed                                            124
# Retired                                                  116
# Other not working                                         33
# Managerial or professional                                86
# Technical, sales, or services                             30
# Other occupation                                          36
# Retired or other not working                             100
# Northeast                                                 80
# Midwest                                                   62
# South                                                     50
# West                                                      62
# Metropolitan statistical area (MSA)                       65
# Non-MSA                                                 35.9
# Owner                                                     90
# Renter or other                                           15
# Less than 25                                             4.3
# 25–49.9                                                   15
# 50–74.9                                                   52
# 75–89.9                                                  198
# 90–100                                                   630
#
#                                            Cash value life insurance  \
# Family characteristic
# Family characteristic                   Cash\nvalue\nlife\ninsurance
# All families                                                    19.4
# Less than 20                                                    12.2
# 20–39.9                                                         15.9
# 40–59.9                                                         19.5
# 60–79.9                                                         22.7
# 80–89.9                                                         22.3
# 90–100                                                            31
# Less than 35                                                     9.3
# 35–44                                                           12.6
# 45–54                                                           18.4
# 55–64                                                           23.4
# 65–74                                                           29.7
# 75 or more                                                      29.5
# Single with child(ren)                                          14.1
# Single, no child, age less than 55                              11.1
# Single, no child, age 55 or more                                22.3
# Couple with child(ren)                                          17.6
# Couple, no child                                                  26
# No high school diploma                                          13.5
# High school diploma                                             20.3
# Some college                                                    17.6
# College degree                                                  22.3
# White non-Hispanic                                              21.2
# Black or African-American non-hispanic                          23.7
# Hispanic or Latino                                               6.4
# Other or Multiple Race                                          14.8
# Working for someone else                                        16.4
# Self-employed                                                   23.3
# Retired                                                         26.1
# ...                                                              ...
# Couple, no child                                                12.6
# No high school diploma                                             5
# High school diploma                                                5
# Some college                                                       5
# College degree                                                    17
# White non-Hispanic                                                10
# Black or African-American non-hispanic                           3.8
# Hispanic or Latino                                               5.5
# Other or Multiple Race                                             5
# Working for someone else                                           8
# Self-employed                                                     25
# Retired                                                          6.7
# Other not working                                                4.8
# Managerial or professional                                        13
# Technical, sales, or services                                    6.5
# Other occupation                                                   7
# Retired or other not working                                     6.5
# Northeast                                                         10
# Midwest                                                           10
# South                                                              6
# West                                                              10
# Metropolitan statistical area (MSA)                                9
# Non-MSA                                                            7
# Owner                                                             10
# Renter or other                                                  3.1
# Less than 25                                                     1.1
# 25–49.9                                                            4
# 50–74.9                                                            8
# 75–89.9                                                         12.6
# 90–100                                                            45
#
#                                         Other managed assets  Other   \
# Family characteristic
# Family characteristic                   Other managed assets  Other
# All families                                             5.5     8.1
# Less than 20                                             2.1     7.8
# 20–39.9                                                  3.9       8
# 40–59.9                                                  3.7     9.4
# 60–79.9                                                  6.7     6.5
# 80–89.9                                                  8.6     7.5
# 90–100                                                  13.3     9.9
# Less than 35                                             1.4     9.3
# 35–44                                                    1.7     6.8
# 45–54                                                    2.6     7.8
# 55–64                                                    6.4     8.8
# 65–74                                                   12.5     7.5
# 75 or more                                              12.6     7.8
# Single with child(ren)                                   3.4    10.5
# Single, no child, age less than 55                       1.7    11.4
# Single, no child, age 55 or more                         8.4     9.8
# Couple with child(ren)                                   3.2     5.8
# Couple, no child                                         8.7     6.6
# No high school diploma                                   2.2     5.3
# High school diploma                                      3.4     8.3
# Some college                                             4.8     8.9
# College degree                                           8.8     8.3
# White non-Hispanic                                       7.3     7.9
# Black or African-American non-hispanic                   1.9     9.9
# Hispanic or Latino                                       1.3     6.5
# Other or Multiple Race                                   2.9     8.2
# Working for someone else                                   3     7.5
# Self-employed                                              9    12.9
# Retired                                                  9.5     7.4
# ...                                                      ...     ...
# Couple, no child                                         143       9
# No high school diploma                                    40       3
# High school diploma                                       85       5
# Some college                                             100       4
# College degree                                           165      10
# White non-Hispanic                                       120       8
# Black or African-American non-hispanic                    50     3.1
# Hispanic or Latino                                        40     3.5
# Other or Multiple Race                                 151.5       4
# Working for someone else                                  74       5
# Self-employed                                            160      10
# Retired                                                  142       9
# Other not working                                          *     1.1
# Managerial or professional                             113.8       8
# Technical, sales, or services                             74       4
# Other occupation                                          25     4.8
# Retired or other not working                             132       6
# Northeast                                                130       5
# Midwest                                                   70     6.5
# South                                                  163.8     5.5
# West                                                     151       5
# Metropolitan statistical area (MSA)                      132     5.5
# Non-MSA                                                   60       3
# Owner                                                    132     9.5
# Renter or other                                           25       2
# Less than 25                                               *     0.7
# 25–49.9                                                   30     3.5
# 50–74.9                                                   50     6.1
# 75–89.9                                                  100      15
# 90–100                                                   264      45
#
#                                           Any financial asset
# Family characteristic
# Family characteristic                   Any\nfinancial\nasset
# All families                                             98.5
# Less than 20                                             95.2
# 20–39.9                                                  97.4
# 40–59.9                                                  99.7
# 60–79.9                                                   100
# 80–89.9                                                   100
# 90–100                                                    100
# Less than 35                                             98.1
# 35–44                                                    97.9
# 45–54                                                      99
# 55–64                                                    98.6
# 65–74                                                    98.9
# 75 or more                                               98.4
# Single with child(ren)                                     98
# Single, no child, age less than 55                       97.4
# Single, no child, age 55 or more                         97.8
# Couple with child(ren)                                   98.8
# Couple, no child                                         99.1
# No high school diploma                                   94.4
# High school diploma                                      98.5
# Some college                                             98.7
# College degree                                           99.7
# White non-Hispanic                                       99.4
# Black or African-American non-hispanic                   96.7
# Hispanic or Latino                                       94.9
# Other or Multiple Race                                   98.6
# Working for someone else                                 98.8
# Self-employed                                            99.4
# Retired                                                  98.4
# ...                                                       ...
# Couple, no child                                         68.1
# No high school diploma                                    1.5
# High school diploma                                        10
# Some college                                             15.3
# College degree                                          123.4
# White non-Hispanic                                       51.5
# Black or African-American non-hispanic                      4
# Hispanic or Latino                                          3
# Other or Multiple Race                                   14.5
# Working for someone else                                 24.2
# Self-employed                                            58.4
# Retired                                                  23.6
# Other not working                                         1.2
# Managerial or professional                               80.5
# Technical, sales, or services                            11.3
# Other occupation                                           10
# Retired or other not working                             14.4
# Northeast                                                36.5
# Midwest                                                  31.6
# South                                                    15.6
# West                                                     22.3
# Metropolitan statistical area (MSA)                        25
# Non-MSA                                                    14
# Owner                                                    69.2
# Renter or other                                           2.5
# Less than 25                                                1
# 25–49.9                                                    10
# 50–74.9                                                  62.1
# 75–89.9                                                 283.9
# 90–100                                                 1292.5
#
# [96 rows x 11 columns]

# %%
years=[1989,1992,1995,1998,2001,2004,2007,2010,2013,2016]
med_prim=[]
for item in list_median:
   med_prim.append(item.loc['Black or African-American non-hispanic'].iloc[1]['Primary residence'])
plt.close('all')
fig,ax=plt.subplots()
ax.plot(years,med_prim)
fig

# %%
plt.close('all')
years=[1989,1992,1995,1998,2001,2004,2007,2010,2013,2016]

low=[]
for item in list_median:
   low.append(item.loc['Less than 20'].iloc[1]['Primary residence'])

high=[]
for item in list_median:
   high.append(item.loc['90–100'].iloc[2]['Primary residence'])
colors = ['teal','#e684ae']
plt.close('all')
fig,(ax,ax2)=plt.subplots(1,2,figsize=(8,3))
ax.plot(years,low,color=colors[0],label='poor',marker='o')
ax.legend()
# ax2 = ax.twinx()
ax2.plot(years,high,color=colors[1],label='rich',marker='o')
ax2.legend()
ax2.fill_between(np.linspace(2007,2009,10), 0, 700,  facecolor='grey', alpha=0.5)

fig

# %%
plt.close('all')
years=[1989,1992,1995,1998,2001,2004,2007,2010,2013,2016]


low=[]
for item in list_median:
   low.append(item.loc['Less than 20'].iloc[1]['Primary residence'])

high=[]
for item in list_median:
   high.append(item.loc['90–100'].iloc[2]['Primary residence'])

financelow=[]
for item in capital_medians:
   financelow.append(item.loc['Less than 20'].iloc[1]['Any financial asset'])

financehigh=[]
for item in capital_medians:
   financehigh.append(item.loc['90–100'].iloc[2]['Any financial asset'])
colors = ['teal','#e684ae']
plt.close('all')
fig,(ax,ax2)=plt.subplots(1,2,figsize=(8,3))
ax.plot(years,np.add(low,financelow)/infrates,color=colors[0],label='poor',marker='o')
ax.legend()
# ax2 = ax.twinx()
ax2.plot(years,np.add(high,financehigh)/infrates,color=colors[1],label='rich',marker='o')
ax2.legend()
ax.fill_between(np.linspace(2007,2009,10), 60, 120,  facecolor='grey', alpha=0.25)

ax2.fill_between(np.linspace(2007,2009,10), 0, 1500,  facecolor='grey', alpha=0.25)
ax.set_ylabel('Median Weath (thousands)')
ax.set_xlabel('Year')
ax2.set_ylabel('Median Weath (thousands)')
ax2.set_xlabel('Year')

# %%
print(high)
print(financehigh)
# Out:
# [200, 180, 175, 225, 300, 450, 500, 475, 475, 550]
# [144, 129, 151.8, 221.5, 368.1, 366.2, 404.5, 550.8, 566.9, 818]

# %%
item.loc['Less than 20']
# Out:
#              Vehicles Primary residence Other residential property  \
# class
# Less than 20     51.6              32.9                        3.7
# Less than 20        2                30                       13.5
#
#              Equity in nonresidential property Business equity Other  \
# class
# Less than 20                               2.3             2.9   5.3
# Less than 20                                10              11     1
#
#              Any nonfinancial asset any asset
# class
# Less than 20                   64.8      78.8
# Less than 20                    8.6       7.6

# %%
inflation=pd.read_csv('cpi.csv')

# %%
inflation.iloc[-300]
# Out:
# Date         1989-02-01
# Index             121.6
# Inflation          0.41
# Name: 913, dtype: object

# %%
233.916/121.6
# Out:
# 1.9236513157894737

# %%
inflation=pd.read_csv('cpi.csv')
infvals=inflation.iloc[0::12][-26:-1][0::3].Index.values
infvals=np.append(infvals,236.525)
infrates=infvals/236.525

# %%
infvals/236.525
# Out:
# array([ 0.51199662,  0.58387063,  0.6354508 ,  0.68322587,  0.74030229,
#         0.78300391,  0.85579114,  0.91612726,  0.97359687,  1.        ])
